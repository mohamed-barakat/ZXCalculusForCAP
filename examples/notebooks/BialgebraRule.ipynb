# %%
using CapAndHomalg
# Out:
# CapAndHomalg v1.6.8
# Imported OSCAR's components GAP and Singular_jll
# Type: ?CapAndHomalg for more information

# %%
LoadPackage( "ZXCalculusForCAP" )

# %%
zx = CategoryOfZXDiagrams_as_CategoryOfCospans_CategoryOfDecoratedQuivers( )
# Out:
# GAP: CategoryOfZXDiagrams( )

# %%
decorated_quivers = UnderlyingCategory( ModelingCategory( zx ) )
# Out:
# GAP: CategoryOfDecoratedQuivers( decorating_quiver )

# %%
Display( zx )
# Out:
# A CAP category with name CategoryOfZXDiagrams( ):
#
# 24 primitive operations were used to derive 90 operations for this category which not yet algorithmically
# * IsRigidSymmetricClosedMonoidalCategory

# %%
one = 1 / zx
# Out:
# GAP: <An object in CategoryOfZXDiagrams( ) representing 1 input/output vertices>

# %%
id = IdentityMorphism( one )
# Out:
# GAP: <An identity morphism in CategoryOfZXDiagrams( )>

# %%
braid = Braiding( one, one )
# Out:
# GAP: <A morphism in CategoryOfZXDiagrams( )>

# %%
Z_0_1 = Z_Spider( zx, 0, 1 )
# Out:
# GAP: <A morphism in CategoryOfZXDiagrams( )>

# %%
Z_1_2 = Z_Spider( zx, 1, 2 )
# Out:
# GAP: <A morphism in CategoryOfZXDiagrams( )>

# %%
X_1_0 = X_Spider( zx, 1, 0 )
# Out:
# GAP: <A morphism in CategoryOfZXDiagrams( )>

# %%
X_2_1 = X_Spider( zx, 2, 1 )
# Out:
# GAP: <A morphism in CategoryOfZXDiagrams( )>

# %%
diagram_bialgebra = (Z_0_1 * Z_1_2 + Z_1_2) * (id + braid + id ) * ( X_2_1 * X_1_0 + X_2_1 )
# Out:
# GAP: <A morphism in CategoryOfZXDiagrams( )>

# %%
diagram7 = ZXInverseIdentityRule( diagram_bialgebra, 7, g"Z" )
# Out:
# GAP: <A morphism in CategoryOfZXDiagrams( )>

# %%
diagram8 = ZXInverseColorChangeRule( diagram7, 10 )
# Out:
# GAP: <A morphism in CategoryOfZXDiagrams( )>

# %%
diagram9 = ZXInverseFusionRule( diagram8, 6 )
# Out:
# GAP: <A morphism in CategoryOfZXDiagrams( )>

# %%
diagram_bialgebra_rewritten = ZXBialgebraRule( diagram_bialgebra, 6, 2, 9, 12 )
# Out:
# GAP: <A morphism in CategoryOfZXDiagrams( )>

# %%
IsWellDefined( diagram_bialgebra_rewritten )
# Out:
# true

# %%
diagram_InverseBilalgebra = ZXInverseBialgebraRule( diagram_bialgebra_rewritten, 7, 8 )
# Out:
# GAP: <A morphism in CategoryOfZXDiagrams( )>

# %%
diagram5 = X_Spider( zx, 0, 1 ) * Z_Spider( zx, 1, 2 )
# Out:
# GAP: <A morphism in CategoryOfZXDiagrams( )>

# %%
diagram_CopyRule = ZXCopyRule( diagram5, 0, 2 )
# Out:
# GAP: <A morphism in CategoryOfZXDiagrams( )>

# %%
diagram6 = Z_1_2 * X_2_1
# Out:
# GAP: <A morphism in CategoryOfZXDiagrams( )>

# %%
diagram_corollary = ZXInverseIdentityRule( diagram6, 2, g"X" )
# Out:
# GAP: <A morphism in CategoryOfZXDiagrams( )>

# %%
diagram_corollary1 = ZXInverseIdentityRule( diagram_corollary, 6, g"Z" )
# Out:
# GAP: <A morphism in CategoryOfZXDiagrams( )>

# %%
diagram_corollary2 = ZXInverseFusionRule( diagram_corollary1, 6 )
# Out:
# GAP: <A morphism in CategoryOfZXDiagrams( )>

# %%
diagram_corollary3 = ZXInverseFusionRule( diagram_corollary2, 8 )
# Out:
# GAP: <A morphism in CategoryOfZXDiagrams( )>

# %%
IsWellDefined( diagram_corollary3 )
# Out:
# true

# %%
diagram_corollary4 = ZXBialgebraRule( diagram_corollary3, 1, 11, 3, 8 )
# Out:
# GAP: <A morphism in CategoryOfZXDiagrams( )>

# %%
diagram_corollory5 = ZXCopyRule( diagram_corollary4, 3, 8 )
# Out:
# GAP: <A morphism in CategoryOfZXDiagrams( )>

# %%
diagram_corollory6 = ZXCopyRule( diagram_corollory5, 3, 5 )
# Out:
# GAP: <A morphism in CategoryOfZXDiagrams( )>

# %%
diagram_corollory7 = ZXCongruenceRule( diagram_corollory6, 4, 6 )
# Out:
# GAP: <A morphism in CategoryOfZXDiagrams( )>
