# %%
using CapAndHomalg
# Out:
# CapAndHomalg v1.6.9
# Imported OSCAR's components GAP and Singular_jll
# Type: ?CapAndHomalg for more information

# %%
LoadPackage( "FunctorCategories" )

# %%
FinQuivers
# Out:
# GAP: FinQuivers

# %%
Display( FinQuivers )
# Out:
# A CAP category with name FinQuivers:
#
# 52 primitive operations were used to derive 356 operations for this category which algorithmically
# * IsCategoryWithDecidableColifts
# * IsCategoryWithDecidableLifts
# * IsEquippedWithHomomorphismStructure
# * IsSymmetricMonoidalCategory
# * IsElementaryTopos
# and furthermore mathematically
# * IsSymmetricMonoidalCategoryStructureGivenByDirectProduct

# %%
ListInstalledOperationsOfCategory( FinQuivers )
# Out:
# GAP: [ "AssociatorLeftToRight", "AssociatorLeftToRightWithGivenTensorProducts", "AssociatorRightToLeft", "AssociatorRightToLeftWithGivenTensorProducts", "AstrictionToCoimage", "AstrictionToCoimageWithGivenCoimageObject", "Braiding", "BraidingInverse", "BraidingInverseWithGivenTensorProducts", "BraidingWithGivenTensorProducts", "CartesianAssociatorLeftToRight", "CartesianAssociatorLeftToRightWithGivenDirectProducts", "CartesianAssociatorRightToLeft", "CartesianAssociatorRightToLeftWithGivenDirectProducts", "CartesianBraiding", "CartesianBraidingInverse", "CartesianBraidingInverseWithGivenDirectProducts", "CartesianBraidingWithGivenDirectProducts", "CartesianDiagonal", "CartesianDiagonalWithGivenCartesianPower", "CartesianDualOnMorphisms", "CartesianDualOnMorphismsWithGivenCartesianDuals", "CartesianDualOnObjects", "CartesianEvaluationForCartesianDual", "CartesianEvaluationForCartesianDualWithGivenDirectProduct", "CartesianLambdaElimination", "CartesianLambdaIntroduction", "CartesianLeftCoevaluationMorphism", "CartesianLeftCoevaluationMorphismWithGivenRange", "CartesianLeftEvaluationMorphism", "CartesianLeftEvaluationMorphismWithGivenSource", "CartesianLeftUnitor", "CartesianLeftUnitorInverse", "CartesianLeftUnitorInverseWithGivenDirectProduct", "CartesianLeftUnitorWithGivenDirectProduct", "CartesianPostComposeMorphism", "CartesianPostComposeMorphismWithGivenObjects", "CartesianPreComposeMorphism", "CartesianPreComposeMorphismWithGivenObjects", "CartesianRightCoevaluationMorphism", "CartesianRightCoevaluationMorphismWithGivenRange", "CartesianRightEvaluationMorphism", "CartesianRightEvaluationMorphismWithGivenSource", "CartesianRightUnitor", "CartesianRightUnitorInverse", "CartesianRightUnitorInverseWithGivenDirectProduct", "CartesianRightUnitorWithGivenDirectProduct", "CartesianSquareOfSubobjectClassifier", "ClassifyingMorphismOfSubobject", "ClassifyingMorphismOfSubobjectWithGivenSubobjectClassifier", "CoastrictionToImage", "CoastrictionToImageWithGivenImageObject", "CocartesianAssociatorLeftToRight", "CocartesianAssociatorLeftToRightWithGivenCoproducts", "CocartesianAssociatorRightToLeft", "CocartesianAssociatorRightToLeftWithGivenCoproducts", "CocartesianBraiding", "CocartesianBraidingInverse", "CocartesianBraidingInverseWithGivenCoproducts", "CocartesianBraidingWithGivenCoproducts", "CocartesianCodiagonal", "CocartesianCodiagonalWithGivenCocartesianMultiple", "CocartesianLeftUnitor", "CocartesianLeftUnitorInverse", "CocartesianLeftUnitorInverseWithGivenCoproduct", "CocartesianLeftUnitorWithGivenCoproduct", "CocartesianRightUnitor", "CocartesianRightUnitorInverse", "CocartesianRightUnitorInverseWithGivenCoproduct", "CocartesianRightUnitorWithGivenCoproduct", "Coequalizer", "CoequalizerFunctorial", "CoequalizerFunctorialWithGivenCoequalizers", "CoimageObject", "CoimageObjectFunctorial", "CoimageObjectFunctorialWithGivenCoimageObjects", "CoimageProjection", "CoimageProjectionWithGivenCoimageObject", "Colift", "ColiftAlongEpimorphism", "Colimit", "ComponentOfMorphismFromCoproduct", "ComponentOfMorphismIntoDirectProduct", "Coproduct", "CoproductFunctorial", "CoproductFunctorialWithGivenCoproducts", "CoproductOnMorphisms", "CoproductOnMorphismsWithGivenCoproducts", "DirectProduct", "DirectProductCartesianDualityCompatibilityMorphism", "DirectProductCartesianDualityCompatibilityMorphismWithGivenObjects", "DirectProductExponentialCompatibilityMorphism", "DirectProductExponentialCompatibilityMorphismWithGivenObjects", "DirectProductFunctorial", "DirectProductFunctorialWithGivenDirectProducts", "DirectProductOnMorphisms", "DirectProductOnMorphismsWithGivenDirectProducts", "DirectProductToExponentialLeftAdjunctMorphism", "DirectProductToExponentialLeftAdjunctMorphismWithGivenExponential", "DirectProductToExponentialLeftAdjunctionIsomorphism", "DirectProductToExponentialLeftAdjunctionIsomorphismWithGivenObjects", "DirectProductToExponentialRightAdjunctMorphism", "DirectProductToExponentialRightAdjunctMorphismWithGivenExponential", "Dire ...

# %%
ModelingCategory( FinQuivers )
# Out:
# GAP: FiniteCocompletion( PathCategory( FinQuiver( "q(V,A)[s:V→A,t:V→A]" ) ) )

# %%
V = FinQuivers.V
# Out:
# GAP: <A projective object in FinQuivers>

# %%
A = FinQuivers.A
# Out:
# GAP: <A projective object in FinQuivers>

# %%
s = FinQuivers.s
# Out:
# GAP: <A monomorphism in FinQuivers>

# %%
t = FinQuivers.t
# Out:
# GAP: <A monomorphism in FinQuivers>

# %%
G = CreateQuiver( 8, [ 0,1,  1,2,  2,3,  3,0,  4,5,  5,5,  2,7,  5,4,  2,7 ] )
# Out:
# GAP: <An object in FinQuivers>

# %%
H = Colimit( [ V, V, V, V, V, V, V, V,
               A, A, A, A, A, A, A, A, A ],
             [ [ 0, s, 8 ],  [ 1, t, 8 ],
               [ 1, s, 9 ],  [ 2, t, 9 ],
               [ 2, s, 10 ], [ 3, t, 10 ],
               [ 3, s, 11 ], [ 0, t, 11 ],
               [ 4, s, 12 ], [ 5, t, 12 ],
               [ 5, s, 13 ], [ 5, t, 13 ],
               [ 2, s, 14 ], [ 7, t, 14 ],
               [ 5, s, 15 ], [ 4, t, 15 ],
               [ 2, s, 16 ], [ 7, t, 16 ],
             ] )
# Out:
# GAP: <An object in FinQuivers>

# %%
G == H
# Out:
# true

# %%
I = Subobject( G, [ 2 ], [ ] )
# Out:
# GAP: <A monomorphism in FinQuivers>

# %%
### ????

# %%
O = Subobject( G, [ 2, 3, 7 ], [ 2, 6, 8 ] )
# Out:
# GAP: <A monomorphism in FinQuivers>
