# %%
using CapAndHomalg
# Out:
# CapAndHomalg v1.6.8
# Imported OSCAR's components GAP and Singular_jll
# Type: ?CapAndHomalg for more information

# %%
LoadPackage( "ZXCalculusForCAP" )

# %%
zx = CategoryOfZXDiagrams_as_CategoryOfCospans_CategoryOfDecoratedQuivers( )
# Out:
# GAP: CategoryOfZXDiagrams( )

# %%
zx_wo_io = UnderlyingCategoryOfZXDiagramsWithoutIO( zx )
# Out:
# GAP: CategoryOfZXDiagramsWithoutIO( CategoryOfDecoratedQuivers( decorating_quiver ) )

# %%
l,r = ZXFusionRule( zx_wo_io, g"Z", 3, 2, 7 );

# %%
Target( l )
# Out:
# GAP: <An object in CategoryOfZXDiagramsWithoutIO( CategoryOfDecoratedQuivers( decorating_quiver ) )>

# %%
l
# Out:
# GAP: <A monomorphism in CategoryOfZXDiagramsWithoutIO( CategoryOfDecoratedQuivers( decorating_quiver ) )>

# %%
r
# Out:
# GAP: <A monomorphism in CategoryOfZXDiagramsWithoutIO( CategoryOfDecoratedQuivers( decorating_quiver ) )>

# %%
Span = CategoryOfSpans( zx_wo_io )
# Out:
# GAP: CategoryOfSpans( CategoryOfZXDiagramsWithoutIO( CategoryOfDecoratedQuivers( decorating_quiver ) ) )

# %%
span = MorphismConstructor( Span, l, r )
# Out:
# GAP: <A morphism in CategoryOfSpans( CategoryOfZXDiagramsWithoutIO( CategoryOfDecoratedQuivers( decorating_quiver ) ) )>

# %%
Display( DotVertexLabelledDigraph( span ) )
# Out:
# //dot
# digraph span_of_ZX_diagrams{
# rankdir="LR"
# minlen=0
# newrank=true
# layout="dot"
# node [shape=circle width=0.2 height=0 style=filled fontsize="10"]
# edge [dir=none fontsize="10"]
#
# subgraph cluster_K {
# label="K"
#
# 0 [xlabel="0" label="" width=0.1 color="black"]
# 1 [xlabel="1" label="" width=0.1 color="black"]
# 2 [xlabel="2" label="" width=0.1 color="black"]
# 3 [xlabel="3" label="" width=0.1 color="black"]
# 4 [xlabel="4" label="" width=0.1 color="black"]
# 5 [xlabel="5" label="" width=0.1 color="black"]
# 6 [xlabel="6" label="" width=0.1 color="black"]
# 7 [xlabel="7" label="" width=0.1 color="black"]
# 8 [xlabel="8" label="" width=0.1 color="black"]
#
# }
#
# subgraph cluster_L {
# style=rounded
# label="L-K"
#
#
# L9 [xlabel="9" label="" color="lightgreen"]
# L10 [xlabel="10" label="" color="lightgreen"]
# }
#
# subgraph cluster_R {
# style=rounded
# label="R-K"
#
#
# R9 [xlabel="9" label="" color="lightgreen"]
# }
#
# 0 -> L9 [constraint=false]
# 1 -> L9 [constraint=false]
# 2 -> L10 [constraint=false]
# 3 -> L10 [constraint=false]
# 4 -> L10 [constraint=false]
# 5 -> L10 [constraint=false]
# 6 -> L10 [constraint=false]
# 7 -> L10 [constraint=false]
# 8 -> L10 [constraint=false]
#
# L9 -> L10 [label="11"]
# L9 -> L10 [label="12"]
# L9 -> L10 [label="13"]
#
# 0 -> R9 [constraint=false]
# 1 -> R9 [constraint=false]
# 2 -> R9 [constraint=false]
# 3 -> R9 [constraint=false]
# 4 -> R9 [constraint=false]
# 5 -> R9 [constraint=false]
# 6 -> R9 [constraint=false]
# 7 -> R9 [constraint=false]
# 8 -> R9 [constraint=false]
#
# }
